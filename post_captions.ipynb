# %% [markdown]
# # Importing Packages

# %%
#import packages and libraries
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
from zipfile import ZipFile
import json
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Extracting Post Captions

# %% [markdown]
# ## JSON 1

# %%
#read json file
joined_post_json_1 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_1.csv')

# %%
joined_post_json_1
# Out:
#         Unnamed: 0  Post ID    Account ID  Sponsorship Label  \
# 0                0        5      alisasia                  0
# 1                1        7      alisasia                  0
# 2                2       15      alisasia                  0
# 3                3       17      alisasia                  1
# 4                4       33      alisasia                  0
# ...            ...      ...           ...                ...
# 249990      249990  1601052  weartoeatiff                  0
# 249991      249991  1601053  weartoeatiff                  0
# 249992      249992  1601056  weartoeatiff                  0
# 249993      249993  1601058  weartoeatiff                  0
# 249994      249994  1601071  weartoeatiff                  0
#
#                        JSON File  \
# 0       1343284435982033594.json
# 1       1344089538574023424.json
# 2       1456845610208901740.json
# 3       1476490497539529413.json
# 4       1709925417879498967.json
# ...

# %%
#import literal_Eval
from ast import literal_eval

# %%
#reset index
joined_post_json_1 = joined_post_json_1.reset_index()
joined_post_json_1
# Out:
#          index  Unnamed: 0  Post ID    Account ID  Sponsorship Label  \
# 0            0           0        5      alisasia                  0
# 1            1           1        7      alisasia                  0
# 2            2           2       15      alisasia                  0
# 3            3           3       17      alisasia                  1
# 4            4           4       33      alisasia                  0
# ...        ...         ...      ...           ...                ...
# 249990  249990      249990  1601052  weartoeatiff                  0
# 249991  249991      249991  1601053  weartoeatiff                  0
# 249992  249992      249992  1601056  weartoeatiff                  0
# 249993  249993      249993  1601058  weartoeatiff                  0
# 249994  249994      249994  1601071  weartoeatiff                  0
#
#                        JSON File  \
# 0       1343284435982033594.json
# 1       1344089538574023424.json
# 2       1456845610208901740.json
# ...

# %% [markdown]
# ### Part 1

# %%
#processing some json content at a time by using literal eval and using lamda funciton to get information from the json file and copying the files to drive which are later combined to create a single csv file. 
post_captions_1 = joined_post_json_1[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_1['File Contents to Dict'] = post_captions_1['File Contents'].apply(lambda x: literal_eval(x))
post_captions_1['Post Caption'] = post_captions_1['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_1 = post_captions_1.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_1.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_1.csv')

# %% [markdown]
# ### Part 2

# %%
post_captions_2 = joined_post_json_1[['Account ID', 'Sponsorship Label', 'File Contents']][125000:]
post_captions_2['File Contents to Dict'] = post_captions_2['File Contents'].apply(lambda x: literal_eval(x))
post_captions_2['Post Caption'] = post_captions_2['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_2 = post_captions_2.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_2.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_2.csv')

# %% [markdown]
# ## JSON 2

# %%
joined_post_json_2 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_2.csv')

# %%
from ast import literal_eval
joined_post_json_2 = joined_post_json_2.reset_index()

# %% [markdown]
# ### Part 3

# %%
post_captions_3 = joined_post_json_2[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_3['File Contents to Dict'] = post_captions_3['File Contents'].apply(lambda x: literal_eval(x))
post_captions_3['Post Caption'] = post_captions_3['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_3 = post_captions_3.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_3.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_3.csv')

# %% [markdown]
# ### Part 4

# %%
post_captions_4 = joined_post_json_2[['Account ID', 'Sponsorship Label', 'File Contents']][125000:]
post_captions_4['File Contents to Dict'] = post_captions_4['File Contents'].apply(lambda x: literal_eval(x))
post_captions_4['Post Caption'] = post_captions_4['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_4 = post_captions_4.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_4.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_4.csv')

# %% [markdown]
# ## JSON 3

# %%
joined_post_json_3 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_3.csv')
from ast import literal_eval
joined_post_json_3 = joined_post_json_3.reset_index()

# %% [markdown]
# ### Part 5

# %%
post_captions_5 = joined_post_json_3[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_5['File Contents to Dict'] = post_captions_5['File Contents'].apply(lambda x: literal_eval(x))
post_captions_5['Post Caption'] = post_captions_5['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_5 = post_captions_5.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_5.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_5.csv')

# %% [markdown]
# ### Part 6

# %%
post_captions_6 = joined_post_json_3[['Account ID', 'Sponsorship Label', 'File Contents']][125000:]
post_captions_6['File Contents to Dict'] = post_captions_6['File Contents'].apply(lambda x: literal_eval(x))
post_captions_6['Post Caption'] = post_captions_6['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_6 = post_captions_6.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_6.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_6.csv')

# %% [markdown]
# ## JSON 4

# %%
joined_post_json_4 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_4.csv')
from ast import literal_eval
joined_post_json_4 = joined_post_json_4.reset_index()

# %% [markdown]
# ### Part 7

# %%
post_captions_7 = joined_post_json_4[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_7['File Contents to Dict'] = post_captions_7['File Contents'].apply(lambda x: literal_eval(x))
post_captions_7['Post Caption'] = post_captions_7['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_7 = post_captions_7.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_7.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_7.csv')

# %% [markdown]
# ### Part 8

# %%
post_captions_8 = joined_post_json_4[['Account ID', 'Sponsorship Label', 'File Contents']][125000:]
post_captions_8['File Contents to Dict'] = post_captions_8['File Contents'].apply(lambda x: literal_eval(x))
post_captions_8['Post Caption'] = post_captions_8['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_8 = post_captions_8.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_8.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_8.csv')

# %% [markdown]
# ## JSON 5

# %%
joined_post_json_5 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_5.csv')
from ast import literal_eval
joined_post_json_5 = joined_post_json_5.reset_index()

# %% [markdown]
# ### Part 9

# %%
post_captions_9 = joined_post_json_5[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_9['File Contents to Dict'] = post_captions_9['File Contents'].apply(lambda x: literal_eval(x))
post_captions_9['Post Caption'] = post_captions_9['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_9 = post_captions_9.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_9.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_9.csv')

# %% [markdown]
# ### Part 10

# %%
post_captions_10 = joined_post_json_5[['Account ID', 'Sponsorship Label', 'File Contents']][125000:]
post_captions_10['File Contents to Dict'] = post_captions_10['File Contents'].apply(lambda x: literal_eval(x))
post_captions_10['Post Caption'] = post_captions_10['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_10 = post_captions_10.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_10.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_10.csv')

# %% [markdown]
# ## JSON 6

# %%
joined_post_json_6 = pd.read_csv("drive/Shareddrives/capstone_prayap_nithyara/" + 'joined_post_json_6.csv')
from ast import literal_eval
joined_post_json_6 = joined_post_json_6.reset_index()

# %% [markdown]
# ### Part 11

# %%
post_captions_11 = joined_post_json_6[['Account ID', 'Sponsorship Label', 'File Contents']][:125000]
post_captions_11['File Contents to Dict'] = post_captions_11['File Contents'].apply(lambda x: literal_eval(x))
post_captions_11['Post Caption'] = post_captions_11['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_11 = post_captions_11.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_11.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_11.csv')

# %% [markdown]
# ### Part 12

# %%
post_captions_12 = joined_post_json_6[['Account ID', 'Sponsorship Label', 'File Contents']][125000:250000]
post_captions_12['File Contents to Dict'] = post_captions_12['File Contents'].apply(lambda x: literal_eval(x))
post_captions_12['Post Caption'] = post_captions_12['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_12 = post_captions_12.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_12.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_12.csv')

# %% [markdown]
# ### Part 13

# %%
post_captions_13 = joined_post_json_6[['Account ID', 'Sponsorship Label', 'File Contents']][250000:]
post_captions_13['File Contents to Dict'] = post_captions_13['File Contents'].apply(lambda x: literal_eval(x))
post_captions_13['Post Caption'] = post_captions_13['File Contents to Dict'].apply(lambda x: x['edge_media_to_caption']['edges'][0]['node']['text'] if len(x['edge_media_to_caption']['edges']) >0  else None)
post_captions_13 = post_captions_13.drop(['File Contents', 'File Contents to Dict'], axis=1)
post_captions_13.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_13.csv')

# %% [markdown]
# # Consolidating Post Captions

# %%
#read all post_captions files
post_captions_1 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_1.csv', lineterminator='\n')
post_captions_2 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_2.csv', lineterminator='\n')
post_captions_3 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_3.csv', lineterminator='\n')
post_captions_4 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_4.csv', lineterminator='\n')
post_captions_5 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_5.csv', lineterminator='\n')
post_captions_6 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_6.csv', lineterminator='\n')
post_captions_7 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_7.csv', lineterminator='\n')
post_captions_8 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_8.csv', lineterminator='\n')
post_captions_9 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_9.csv', lineterminator='\n')
post_captions_10 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_10.csv', lineterminator='\n')
post_captions_11 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_11.csv', lineterminator='\n')
post_captions_12 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_12.csv', lineterminator='\n')
post_captions_13 = pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_13.csv', lineterminator='\n')

# %%
#combine all files into one dataframe
post_captions_combined = pd.concat([post_captions_1, post_captions_2, post_captions_3, post_captions_4, post_captions_5, post_captions_6, post_captions_7, post_captions_8, post_captions_9, post_captions_10, post_captions_11, post_captions_12, post_captions_13]).reset_index()

# %%
#drop index
post_captions_combined = post_captions_combined.drop(['index', 'Unnamed: 0'], axis=1)
post_captions_combined
# Out:
#            Account ID  Sponsorship Label  \
# 0            alisasia                  0
# 1            alisasia                  0
# 2            alisasia                  0
# 3            alisasia                  1
# 4            alisasia                  0
# ...               ...                ...
# 1601069  weartoeatiff                  0
# 1601070  weartoeatiff                  0
# 1601071  weartoeatiff                  0
# 1601072  weartoeatiff                  0
# 1601073  weartoeatiff                  0
#
#                                               Post Caption
# 0        I always post all my going out outfits on Snap...
# 1                                        @donalovehair 💜💜💜
# 2                             @romwe_fashion hoodie jacket
# 3        @kraft_macandcheese takes only 10 min to prepa...
# 4        “Walkin' around with a bad bitch, she a barbie...
# ...                                                    ...
# ...

# %%
#export to drive
post_captions_combined.to_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_combined.csv')

# %% [markdown]
# # Sentiment Analysis

# %%
#install vader sentiment and import sentiment analyzer
! pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# ...
#      |████████████████████████████████| 125 kB 8.4 MB/s
# ...

# %%
#intilializing sentiment intensity analyzer
sent_obj = SentimentIntensityAnalyzer()

# %%
#test dataframe
test = post_captions_combined

# %%
#applying sentiment analyzer on the post captions
test['Compound Sentiment'] = test['Post Caption'].apply(lambda x: sent_obj.polarity_scores(str(x))['compound'])

# %% [markdown]
# # Caption Length

# %%
#dropping NANs
test = post_captions_combined.dropna()
test = post_captions_combined

# %%
#converting caption to string and getting a length
test['Post Caption'] = test['Post Caption'].apply(lambda x: str(x))
test['Caption Length'] = test['Post Caption'].apply(lambda x: len(x))

# %% [markdown]
# #Hashtags and Emojis

# %%
#read data from drive
post=pd.read_csv('drive/Shareddrives/capstone_prayap_nithyara/post_captions_combined.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,1,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#import libraries and create a function to extract hashtags
import re
hash = []
def hash_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    #for i in x:
    ht = re.findall(r"#(\w+)", x)
    if ht !=[]:
      hashtags=ht
      totaltags=len(ht)
    else:
      hashtags=[]
      totaltags=0
    return (hashtags,totaltags)
# extracting hashtags from positive tweets
# extracting hashtags from  tweets
post['hashtag']= post['Post Caption'].apply(lambda x: hash_extract(str(x))[0])
post['total_hashtags']=post['Post Caption'].apply(lambda x: hash_extract(str(x))[1])

# %%
#dataframe of hashtags loop
post[['hashtag','total_hashtags']].sort_values(by=['total_hashtags'],ascending=False)
# Out:
#                                                    hashtag  total_hashtags
# 1419325  [seasonalsaturdays, thehighlightofyourday, ext...              66
# 3846729  [picoftheday, photooftheday, me, girl, italian...              64
# 2790529  [breakthegram, wakeupandmakeup, makeupaddict, ...              64
# 2712018  [makeup, mua, makeupartist, selftaught, selfta...              62
# 2624077  [gelato, icecream, dessert, dessertporn, desse...              62
# ...                                                    ...             ...
# 1851699                                                 []               0
# 1851700                                                 []               0
# 1851701                                                 []               0
# 1851702                                                 []               0
# 2076608                                                 []               0
#
# [4153216 rows x 2 columns]

# %%
#install emoji library
pip install emoji --upgrade
# Out:
# ...
#      |████████████████████████████████| 175 kB 27.9 MB/s
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=5553c65818dde1c89debafc0f02b6d887ab7af0067ccad0f30671cea2d510bd0
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# ...

# %%
#import emoji and extract emoji and create a counter
import emoji
from collections import Counter
post['emoji_text']= post['Post Caption'].apply(lambda x: re.findall(r'(:[!_\-\w]+:)',emoji.demojize(str(x))))
post['emoji']= post['emoji_text'].apply(lambda x: [emoji.emojize(em) for em in x])
post['emoji_counter']=post['emoji'].apply(lambda x: Counter(x))

# %%
#copy file with emoji into drive
post.to_csv( "influencers_posts_emoji_hashtag.csv", index=False, encoding='utf-8-sig')
# !cp influencers_posts_emoji_hashtag.csv "/content/drive/Shareddrives/capstone_prayap_nithyara"

# %% [markdown]
# #Combine

# %%
#import datafrom drive
post=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/influencers_posts_emoji_hashtag.csv')
post.head()

# %%
#merge dataframes
combinedf=pd.merge(test,post,on=['Post Caption'])

# %%
#copy to drive
combinedf.to_csv( "influencers_posts_sentiment_emoji_hashtag.csv", index=False, encoding='utf-8-sig')
# !cp influencers_posts_emoji_hashtag.csv "/content/drive/Shareddrives/capstone_prayap_nithyara/"
# Out:
# cp: cannot stat 'influencers_posts_emoji_hashtag.csv': No such file or directory

# %% [markdown]
# #WordCloud

# %%
#read data from drive
combineddf=pd.read_csv("/content/drive/Shareddrives/capstone_prayap_nithyara/influencers_posts_sentiment_emoji_hashtag.csv")

# %%
#import wordcloud library
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#create a function for wordcloud all text by removing stopwords
def wordcloud_alltext(df):
    stopwords = set(STOPWORDS)
    list1='.'.join(df['Post Caption'])
    wordcloud = WordCloud(collocations=False,stopwords=stopwords, background_color="white").generate(list1[:10000000])
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
positivedf=combineddf[combineddf['Compound Sentiment']>0.5]
negativedf=combineddf[combineddf['Compound Sentiment']<0.5]

# %%
wordcloud_alltext(combineddf)

# %%
#import libraries
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import functools
import operator
import re
#create a function for wordcloud all text by removing stopwords

def wordcloud_hashtags(df):
    stopwords = set(STOPWORDS)

    list2=df['hashtag'].tolist()

    words1=[]
    for a in list2:
      if a!='[]':
        
        words1.append(re.sub( '[^a-z0-9]', ' ', a))
    all_words = '.'.join([text for text in words1])
    wordcloud = WordCloud(collocations=False,stopwords=stopwords, background_color="white").generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
#wordcloud of hashtags full dataframe
wordcloud_hashtags(combineddf)

# %%
#wordcloud positive sentiment
wordcloud_hashtags(positivedf)

# %%
#wordcloud negative sentiment
wordcloud_hashtags(negativedf)

# %%
#install emoji
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 175 kB 7.9 MB/s
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=ca3ad8072bc1c54591150aa66481b37fc8564db8ea190c4203c93a91cc75149e
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# ...

# %%
#convert to strings
# brandstring=list((map(lambda x: str(x), brands_keywords_list)))
import re
import string
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import functools
import operator
import emoji
#NLP processing create functions to remove punctuation, extrawhite space, hex values, stopwords, emojis, links
def removePunct(sent):    
  sent = "".join([char for char in sent if char not in string.punctuation]) 
  return sent

def removeExtraWhitespaces(sent):
  sent = re.sub('\s+', ' ', sent).strip()
  return sent

def removeHex(sent):
  sent = re.sub(r"\\[a-z][a-z]?[0-9]+",r'', sent)
  return sent

def removestopwords(sent):
  stop_words=STOPWORDS
  word_list=sent.split()
  clean_sentence=' '.join([w for w in word_list if w.lower() not in stop_words])
  return(clean_sentence)

def removeemoji(sent):
  new_text = re.sub(emoji.get_emoji_regexp(), r"", sent)
  return new_text 
def removelinks(sent):
  string = re.sub(r'http//t.co\/[^\s]+', '', sent, flags=re.MULTILINE)
  return(string)

# %% [markdown]
# NLP FULL TEXT

# %%
#performing NLP on text to convert caption to simple text
combineddf['sim_text']=combineddf['Post Caption'].apply(lambda x :removeExtraWhitespaces(x))
combineddf['sim_text']=combineddf['sim_text'].apply(lambda x :removePunct(x) )
combineddf['sim_text']=combineddf['sim_text'].apply(lambda x :removeHex(x) )
combineddf['sim_text']=combineddf['sim_text'].apply(lambda x :removestopwords(x) )
combineddf['sim_text']=combineddf['sim_text'].apply(lambda x :removeemoji(x) )
combineddf['sim_text']=combineddf['sim_text'].apply(lambda x :removelinks(x) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'

# %%
#copy file to drive
combineddf.to_csv( "influencers_posts_sentiment_emoji_hashtag_cleantext.csv", index=False, encoding='utf-8-sig')
# !cp influencers_posts_sentiment_emoji_hashtag_cleantext.csv "/content/drive/Shareddrives/capstone_prayap_nithyara/"

# %%
#read file
textdf=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/influencers_posts_sentiment_emoji_hashtag_cleantext.csv')

# %%
#create sponsored dataframe
sponsoreddf=textdf[textdf['Sponsorship Label_x']==1]

# %%
#import libraries
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import functools
import operator
import re
#create wordcloud function for all text
def wordcloud_text(df):
    stopwords = set(STOPWORDS)
    #df['word_list']=df['text'].apply()
    list2=df['sim_text'].tolist()

    all_words = '.'.join([str(text) for text in list2])

    wordcloud = WordCloud(collocations=False,stopwords=stopwords, background_color="white").generate(all_words)

    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
#wordcloud of sponsore dposts.
wordcloud_text(sponsoreddf)

# %%
#create a nonsponsored post dataframe and copy in drive
nonsponsoreddf1=textdf[textdf['Sponsorship Label_x']==0][['emoji_text','emoji']]
nonsponsoreddf1.to_csv( "nonsponsored_cleantext_emojinonsponsored.csv", index=False, encoding='utf-8-sig')
# !cp nonsponsored_cleantext_emojinonsponsored.csv "/content/drive/Shareddrives/capstone_prayap_nithyara/"

# %%
#read nonsponsored post text
nonsponsoreddf=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/nonsponsored_cleantext.csv')

# %%
#create wordcloud of nonsponsoreddf
wordcloud_text(nonsponsoreddf[:400000])

# %% [markdown]
# What types of patterns or similarities can we find among influencers?
# see the word clouds here. Others see exploratory analysis. and blogposts

# %% [markdown]
# EMOJIS

# %% [markdown]
# # EmojiCloud
#
# This portion uses a code from a function created by to create emoji cloud similar to wordcloud  of the emojis

# %%
#import livraries and create function for wordcloud of emojis
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import functools
import operator
import re
def wordcloud_emoji(df):
    stopwords = set(STOPWORDS)
    list2=df['emoji_text'].tolist()
    all_words = '.'.join([str(text) for text in list2])
    wordcloud = WordCloud(collocations=False,stopwords=stopwords, background_color="white").generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
#create wordcloud of emojis for sponsored
wordcloud_emoji(sponsoreddf)

# %%
#nonsponsored posts
nonsponsoreddf1=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/nonsponsored_cleantext_emojinonsponsored.csv')

# %%
#create wordcloud of emojis for non-sponsored posts

wordcloud_emoji(nonsponsoreddf1)

# %%
#import data from drive
textdf=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/influencers_posts_sentiment_emoji_hashtag_cleantext.csv')

# %%
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#function to create a stem sentence
def stemsen(sentence):
    token_words=word_tokenize(sentence)
    token_words
    sen_stem=[]
    for word in token_words:
        sen_stem.append(word)
        sen_stem.append(" ")
    return "".join(sen_stem)

# %%
#using function to create stemwords sentence
lemmatizer = WordNetLemmatizer()
textdf['stem_sen']=textdf['sim_text'].apply(lambda x: stemsen(str(x)))

# %%
#copy to drive that includes stem sentence
textdf.to_csv( "word_stem.csv", index=False, encoding='utf-8-sig')
# !cp word_stem.csv "/content/drive/Shareddrives/capstone_prayap_nithyara/"

# %%
#read data from drive
textdf1=pd.read_csv("/content/drive/Shareddrives/capstone_prayap_nithyara/word_stem.csv")

# %%
#create sponsored
sponsoreddf2=textdf1[textdf1['Sponsorship Label_x']==1]

# %%
#create nonsponsored
nonsponsoreddf2=textdf1[textdf1['Sponsorship Label_x']==0]

# %%
#copy nonsponsored to drive
nonsponsoreddf2.to_csv( "word_stem_nonsponsored.csv", index=False, encoding='utf-8-sig')
# !cp word_stem_nonsponsored.csv "/content/drive/Shareddrives/capstone_prayap_nithyara/"

# %%
#read data from drive
nonsponsoreddf2=pd.read_csv("/content/drive/Shareddrives/capstone_prayap_nithyara/word_stem_nonsponsored.csv")

# %%
#import libraries
#function for wordcloud of stemwords
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import functools
import operator
import re
#create wordcloud function for all text
def wordcloud_text1(df):
    stopwords = set(STOPWORDS)
    #df['word_list']=df['text'].apply()
    list2=df['stem_sen'].tolist()

    all_words = '.'.join([str(text) for text in list2])

    wordcloud = WordCloud(collocations=False,stopwords=stopwords, background_color="white").generate(all_words)

    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
#create wordcloud of stemwords for sponsored posts
wordcloud_text1(sponsoreddf2)

# %%
#create wordcloud of stemwords for nonsponsored posts
wordcloud_text1(nonsponsoreddf2[:400000])

# %%
#create histogram of compound sentiment
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
textdf.hist(column='Compound Sentiment', bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efea8abc8d0>]],
#       dtype=object)

# %%
#create histogram of compound sentiment of sponsored posts
#import libraries
sponsoreddf['Compound Sentiment'].plot(kind='hist',grid=False,
        figsize=(10, 4),
        legend=True,
        bins=30,
        orientation='vertical',
        title='Histogram of Compound Sentiment for Sponsored Instagram Posts',
        color='#FFCF56')
plt.xlabel('Compound Sentiment')
plt.ylabel("Number Of Instagram Posts")
# Out:
# Text(0, 0.5, 'Number Of Instagram Posts')

# %%
#nonsponsored df
nonsponsoreddf3=textdf[textdf['Sponsorship Label_x']==0]

# %%
#create histogram of compound sentiment of nonsponsored posts
#import libraries
nonsponsoreddf3['Compound Sentiment'].plot(kind='hist',grid=False,
        figsize=(10, 4),
        legend=True,
        bins=30,
        orientation='vertical',
        title='Histogram of Compound Sentiment for Non-Sponsored Instagram Posts',
        color='#FFCF56')
plt.xlabel('Compound Sentiment')
plt.ylabel("Number Of Instagram Posts")
# Out:
# Text(0, 0.5, 'Number Of Instagram Posts')

# %%
#read data for influencer dataset
modeldf=pd.read_csv('/content/drive/Shareddrives/capstone_prayap_nithyara/models/model_input.csv')

# %%
#influencer list by popularity
inflistbypopularity=modeldf.sort_values(by='pgr',ascending=False)

# %%
#top 50 influencers by popularity
inflistbypopularity.head(50)
# Out:
#                    Account ID                                           Name  \
# 3226           priyankachopra                                Priyanka Chopra
# 12895               gigihadid                                     Gigi Hadid
# 21827             taylor_hill                                    Taylor Hill
# 33966             dovecameron                   \xe2\x99\xa1DOVE\xe2\x99\xa1
# 34237          vanessahudgens                                Vanessa Hudgens
# 28198         thenotoriousmma                        Conor McGregor Official
# 33037     thebucketlistfamily                         The Bucket List Family
# 631                 model_roz                                      MODEL ROZ
# 18786                tommiee_                                         Tommie
# 24865           patrickstarrr                                  patrickstarrr
# 12059                 simaria                                 Simaria Mendes
# ...

# %%
#influencer list by followers and getting top 50 list
inflistbyfollowers=modeldf.sort_values(by='af',ascending=False)
inflistbyfollowers.head(50)
# Out:
#                 Account ID                                            Name  \
# 30042        kimkardashian                             Kim Kardashian West
# 23221        kendalljenner                                         Kendall
# 790                    jlo                                  Jennifer Lopez
# 20280      khloekardashian                                    Khlo\xc3\xa9
# 12895            gigihadid                                      Gigi Hadid
# 17704            kingjames                                    LeBron James
# 10031       caradelevingne                                 Cara Delevingne
# 25484               anitta                         anitta \xf0\x9f\x8e\xa4
# 34237       vanessahudgens                                 Vanessa Hudgens
# 28198      thenotoriousmma                         Conor McGregor Official
# 3226        priyankachopra                                 Priyanka Chopra
# ...

# %%
#influencer list by posts and getting top 50 list

inflistbyposts=modeldf.sort_values(by='npos',ascending=False)
inflistbyposts.head(50)
# Out:
#                          Account ID  \
# 994                     curvynstyle
# 33175             barbershopconnect
# 18000                  theshaderoom
# 19947             paperazzimagazine
# 4794                  hellopakistan
# 19071                nichelifestyle
# 16124          divamagazinepakistan
# 1082       classandfashion_official
# 19561                  paulyhudgens
# 8965                      snoopdogg
# 24267                     crunk.inc
# 4045   thatkenyanphotojournalist254
# 21416                   divah_filez
# 30344               world_of_asians
# 20094         msamypromoqueenfoster
# 35900             wrestlingfan_1995
# 4282               plaincigarillos_
# 37324                 barbersince98
# 12397                       kaleo63
# 25954                  plusmodelmag
# 33671                  rosaa_guzman
# 24890                      mbahrain
# 13600                   kinks2curls
# 23121                       complex
# 13793                venenosandoval
# ...
